# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import

# %%
import random
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import os
import re
import glob
import cv2

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
import torchvision.models as models

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings(action='ignore')

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# ## Hyperparameter Setting

# %%
CFG = {
    'IMG_SIZE':224,
    'EPOCHS':30,
    'LEARNING_RATE':0.5, #3e-4,
    'BATCH_SIZE':128,
    'SEED':41
}

# %% [markdown]
# ## Fixed RandomSeed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ## Data Pre-processing

# %%
all_img_list = glob.glob('drive/MyDrive/Doedal/train/*/*')

# %%
all_img_list
# Out:
# ['drive/MyDrive/Doedal/train/걸레받이수정/111.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/11.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/175.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/178.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/20.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/87.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/28.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/72.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/94.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/26.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/164.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/71.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/239.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/209.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/159.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/57.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/235.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/98.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/174.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/118.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/86.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/198.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/101.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/169.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/22.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/115.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/245.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/138.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/88.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/304.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/157.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/146.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/18.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/202.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/38.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/122.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/189.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/290.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/195.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/16.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/89.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/186.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/141.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/220.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/149.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/302.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/70.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/297.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/259.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/97.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/282.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/46.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/0.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/129.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/75.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/283.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/288.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/242.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/230.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/91.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/108.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/299.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/36.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/31.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/196.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/5.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/33.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/286.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/44.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/29.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/41.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/3.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/205.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/2.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/64.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/222.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/78.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/113.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/56.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/140.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/217.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/197.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/232.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/298.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/211.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/152.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/267.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/226.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/65.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/236.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/177.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/49.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/63.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/287.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/51.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/8.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/151.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/1.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/204.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/119.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/43.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/12.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/219.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/84.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/76.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/250.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/208.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/117.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/170.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/252.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/153.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/85.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/59.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/54.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/80.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/19.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/171.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/105.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/133.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/103.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/60.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/24.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/121.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/127.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/277.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/45.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/123.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/30.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/296.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/27.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/66.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/231.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/182.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/124.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/221.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/139.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/42.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/35.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/32.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/247.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/155.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/176.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/144.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/244.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/158.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/191.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/99.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/256.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/79.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/37.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/168.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/95.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/126.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/215.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/17.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/301.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/50.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/246.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/193.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/213.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/109.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/106.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/306.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/104.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/272.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/143.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/237.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/210.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/254.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/295.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/7.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/300.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/83.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/160.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/201.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/96.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/167.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/23.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/218.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/293.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/268.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/279.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/163.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/179.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/21.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/145.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/161.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/224.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/200.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/82.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/261.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/266.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/125.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/264.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/258.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/34.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/154.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/289.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/257.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/73.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/253.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/69.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/225.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/207.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/53.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/116.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/132.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/238.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/166.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/184.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/147.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/284.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/137.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/165.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/227.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/180.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/263.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/136.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/107.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/74.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/291.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/13.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/61.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/150.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/100.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/39.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/265.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/280.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/187.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/243.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/58.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/10.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/62.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/269.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/241.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/216.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/102.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/233.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/112.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/183.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/4.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/114.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/229.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/271.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/273.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/203.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/162.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/303.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/285.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/47.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/25.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/292.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/81.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/52.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/212.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/14.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/172.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/148.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/248.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/135.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/274.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/262.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/92.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/234.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/40.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/192.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/93.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/249.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/188.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/67.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/270.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/223.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/128.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/228.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/305.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/77.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/130.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/120.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/173.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/185.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/190.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/90.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/275.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/156.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/55.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/255.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/251.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/260.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/194.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/48.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/134.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/15.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/199.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/181.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/131.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/68.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/110.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/9.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/214.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/294.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/142.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/6.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/281.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/206.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/278.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/240.png',
#  'drive/MyDrive/Doedal/train/걸레받이수정/276.png',
#  'drive/MyDrive/Doedal/train/녹오염/5.png',
#  'drive/MyDrive/Doedal/train/녹오염/13.png',
#  'drive/MyDrive/Doedal/train/녹오염/11.png',
#  'drive/MyDrive/Doedal/train/녹오염/8.png',
#  'drive/MyDrive/Doedal/train/녹오염/1.png',
#  'drive/MyDrive/Doedal/train/녹오염/4.png',
#  'drive/MyDrive/Doedal/train/녹오염/6.png',
#  'drive/MyDrive/Doedal/train/녹오염/0.png',
#  'drive/MyDrive/Doedal/train/녹오염/9.png',
#  'drive/MyDrive/Doedal/train/녹오염/10.png',
#  'drive/MyDrive/Doedal/train/녹오염/7.png',
#  'drive/MyDrive/Doedal/train/녹오염/3.png',
#  'drive/MyDrive/Doedal/train/녹오염/2.png',
#  'drive/MyDrive/Doedal/train/녹오염/12.png',
#  'drive/MyDrive/Doedal/train/석고수정/46.png',
#  'drive/MyDrive/Doedal/train/석고수정/16.png',
#  'drive/MyDrive/Doedal/train/석고수정/1.png',
#  'drive/MyDrive/Doedal/train/석고수정/15.png',
#  'drive/MyDrive/Doedal/train/석고수정/25.png',
#  'drive/MyDrive/Doedal/train/석고수정/37.png',
#  'drive/MyDrive/Doedal/train/석고수정/19.png',
#  'drive/MyDrive/Doedal/train/석고수정/35.png',
#  'drive/MyDrive/Doedal/train/석고수정/32.png',
#  'drive/MyDrive/Doedal/train/석고수정/27.png',
#  'drive/MyDrive/Doedal/train/석고수정/7.png',
#  'drive/MyDrive/Doedal/train/석고수정/24.png',
#  'drive/MyDrive/Doedal/train/석고수정/56.png',
#  'drive/MyDrive/Doedal/train/석고수정/50.png',
#  'drive/MyDrive/Doedal/train/석고수정/52.png',
#  'drive/MyDrive/Doedal/train/석고수정/54.png',
#  'drive/MyDrive/Doedal/train/석고수정/36.png',
#  'drive/MyDrive/Doedal/train/석고수정/11.png',
#  'drive/MyDrive/Doedal/train/석고수정/31.png',
#  'drive/MyDrive/Doedal/train/석고수정/41.png',
#  'drive/MyDrive/Doedal/train/석고수정/13.png',
#  'drive/MyDrive/Doedal/train/석고수정/10.png',
#  'drive/MyDrive/Doedal/train/석고수정/28.png',
#  'drive/MyDrive/Doedal/train/석고수정/17.png',
#  'drive/MyDrive/Doedal/train/석고수정/45.png',
#  'drive/MyDrive/Doedal/train/석고수정/4.png',
#  'drive/MyDrive/Doedal/train/석고수정/12.png',
#  'drive/MyDrive/Doedal/train/석고수정/5.png',
#  'drive/MyDrive/Doedal/train/석고수정/3.png',
#  'drive/MyDrive/Doedal/train/석고수정/55.png',
#  'drive/MyDrive/Doedal/train/석고수정/47.png',
#  'drive/MyDrive/Doedal/train/석고수정/0.png',
#  'drive/MyDrive/Doedal/train/석고수정/51.png',
#  'drive/MyDrive/Doedal/train/석고수정/39.png',
#  'drive/MyDrive/Doedal/train/석고수정/22.png',
#  'drive/MyDrive/Doedal/train/석고수정/49.png',
#  'drive/MyDrive/Doedal/train/석고수정/33.png',
#  'drive/MyDrive/Doedal/train/석고수정/21.png',
#  'drive/MyDrive/Doedal/train/석고수정/40.png',
#  'drive/MyDrive/Doedal/train/석고수정/14.png',
#  'drive/MyDrive/Doedal/train/석고수정/18.png',
#  'drive/MyDrive/Doedal/train/석고수정/38.png',
#  'drive/MyDrive/Doedal/train/석고수정/6.png',
#  'drive/MyDrive/Doedal/train/석고수정/34.png',
#  'drive/MyDrive/Doedal/train/석고수정/26.png',
#  'drive/MyDrive/Doedal/train/석고수정/9.png',
#  'drive/MyDrive/Doedal/train/석고수정/23.png',
#  'drive/MyDrive/Doedal/train/석고수정/44.png',
#  'drive/MyDrive/Doedal/train/석고수정/30.png',
#  'drive/MyDrive/Doedal/train/석고수정/48.png',
#  'drive/MyDrive/Doedal/train/석고수정/53.png',
#  'drive/MyDrive/Doedal/train/석고수정/8.png',
#  'drive/MyDrive/Doedal/train/석고수정/20.png',
#  'drive/MyDrive/Doedal/train/석고수정/2.png',
#  'drive/MyDrive/Doedal/train/석고수정/42.png',
#  'drive/MyDrive/Doedal/train/석고수정/29.png',
#  'drive/MyDrive/Doedal/train/석고수정/43.png',
#  'drive/MyDrive/Doedal/train/꼬임/70.png',
#  'drive/MyDrive/Doedal/train/꼬임/22.png',
#  'drive/MyDrive/Doedal/train/꼬임/154.png',
#  'drive/MyDrive/Doedal/train/꼬임/183.png',
#  'drive/MyDrive/Doedal/train/꼬임/62.png',
#  'drive/MyDrive/Doedal/train/꼬임/4.png',
#  'drive/MyDrive/Doedal/train/꼬임/184.png',
#  'drive/MyDrive/Doedal/train/꼬임/91.png',
#  'drive/MyDrive/Doedal/train/꼬임/28.png',
#  'drive/MyDrive/Doedal/train/꼬임/104.png',
#  'drive/MyDrive/Doedal/train/꼬임/49.png',
#  'drive/MyDrive/Doedal/train/꼬임/156.png',
#  'drive/MyDrive/Doedal/train/꼬임/84.png',
#  'drive/MyDrive/Doedal/train/꼬임/153.png',
#  'drive/MyDrive/Doedal/train/꼬임/85.png',
#  'drive/MyDrive/Doedal/train/꼬임/150.png',
#  'drive/MyDrive/Doedal/train/꼬임/76.png',
#  'drive/MyDrive/Doedal/train/꼬임/60.png',
#  'drive/MyDrive/Doedal/train/꼬임/100.png',
#  'drive/MyDrive/Doedal/train/꼬임/25.png',
#  'drive/MyDrive/Doedal/train/꼬임/59.png',
#  'drive/MyDrive/Doedal/train/꼬임/152.png',
#  'drive/MyDrive/Doedal/train/꼬임/208.png',
#  'drive/MyDrive/Doedal/train/꼬임/157.png',
#  'drive/MyDrive/Doedal/train/꼬임/107.png',
#  'drive/MyDrive/Doedal/train/꼬임/169.png',
#  'drive/MyDrive/Doedal/train/꼬임/147.png',
#  'drive/MyDrive/Doedal/train/꼬임/186.png',
#  'drive/MyDrive/Doedal/train/꼬임/37.png',
#  'drive/MyDrive/Doedal/train/꼬임/61.png',
#  'drive/MyDrive/Doedal/train/꼬임/65.png',
#  'drive/MyDrive/Doedal/train/꼬임/172.png',
#  'drive/MyDrive/Doedal/train/꼬임/48.png',
#  'drive/MyDrive/Doedal/train/꼬임/1.png',
#  'drive/MyDrive/Doedal/train/꼬임/145.png',
#  'drive/MyDrive/Doedal/train/꼬임/75.png',
#  'drive/MyDrive/Doedal/train/꼬임/189.png',
#  'drive/MyDrive/Doedal/train/꼬임/142.png',
#  'drive/MyDrive/Doedal/train/꼬임/14.png',
#  'drive/MyDrive/Doedal/train/꼬임/54.png',
#  'drive/MyDrive/Doedal/train/꼬임/12.png',
#  'drive/MyDrive/Doedal/train/꼬임/168.png',
#  'drive/MyDrive/Doedal/train/꼬임/64.png',
#  'drive/MyDrive/Doedal/train/꼬임/143.png',
#  'drive/MyDrive/Doedal/train/꼬임/198.png',
#  'drive/MyDrive/Doedal/train/꼬임/40.png',
#  'drive/MyDrive/Doedal/train/꼬임/95.png',
#  'drive/MyDrive/Doedal/train/꼬임/11.png',
#  'drive/MyDrive/Doedal/train/꼬임/30.png',
#  'drive/MyDrive/Doedal/train/꼬임/82.png',
#  'drive/MyDrive/Doedal/train/꼬임/191.png',
#  'drive/MyDrive/Doedal/train/꼬임/167.png',
#  'drive/MyDrive/Doedal/train/꼬임/110.png',
#  'drive/MyDrive/Doedal/train/꼬임/66.png',
#  'drive/MyDrive/Doedal/train/꼬임/132.png',
#  'drive/MyDrive/Doedal/train/꼬임/50.png',
#  'drive/MyDrive/Doedal/train/꼬임/31.png',
#  'drive/MyDrive/Doedal/train/꼬임/122.png',
#  'drive/MyDrive/Doedal/train/꼬임/159.png',
#  'drive/MyDrive/Doedal/train/꼬임/175.png',
#  'drive/MyDrive/Doedal/train/꼬임/39.png',
#  'drive/MyDrive/Doedal/train/꼬임/44.png',
#  'drive/MyDrive/Doedal/train/꼬임/78.png',
#  'drive/MyDrive/Doedal/train/꼬임/10.png',
#  'drive/MyDrive/Doedal/train/꼬임/194.png',
#  'drive/MyDrive/Doedal/train/꼬임/193.png',
#  'drive/MyDrive/Doedal/train/꼬임/165.png',
#  'drive/MyDrive/Doedal/train/꼬임/72.png',
#  'drive/MyDrive/Doedal/train/꼬임/21.png',
#  'drive/MyDrive/Doedal/train/꼬임/27.png',
#  'drive/MyDrive/Doedal/train/꼬임/92.png',
#  'drive/MyDrive/Doedal/train/꼬임/33.png',
#  'drive/MyDrive/Doedal/train/꼬임/121.png',
#  'drive/MyDrive/Doedal/train/꼬임/24.png',
#  'drive/MyDrive/Doedal/train/꼬임/2.png',
#  'drive/MyDrive/Doedal/train/꼬임/170.png',
#  'drive/MyDrive/Doedal/train/꼬임/171.png',
#  'drive/MyDrive/Doedal/train/꼬임/160.png',
#  'drive/MyDrive/Doedal/train/꼬임/0.png',
#  'drive/MyDrive/Doedal/train/꼬임/8.png',
#  'drive/MyDrive/Doedal/train/꼬임/46.png',
#  'drive/MyDrive/Doedal/train/꼬임/138.png',
#  'drive/MyDrive/Doedal/train/꼬임/5.png',
#  'drive/MyDrive/Doedal/train/꼬임/56.png',
#  'drive/MyDrive/Doedal/train/꼬임/13.png',
#  'drive/MyDrive/Doedal/train/꼬임/139.png',
#  'drive/MyDrive/Doedal/train/꼬임/16.png',
#  'drive/MyDrive/Doedal/train/꼬임/166.png',
#  'drive/MyDrive/Doedal/train/꼬임/29.png',
#  'drive/MyDrive/Doedal/train/꼬임/116.png',
#  'drive/MyDrive/Doedal/train/꼬임/17.png',
#  'drive/MyDrive/Doedal/train/꼬임/90.png',
#  'drive/MyDrive/Doedal/train/꼬임/144.png',
#  'drive/MyDrive/Doedal/train/꼬임/38.png',
#  'drive/MyDrive/Doedal/train/꼬임/120.png',
#  'drive/MyDrive/Doedal/train/꼬임/109.png',
#  'drive/MyDrive/Doedal/train/꼬임/47.png',
#  'drive/MyDrive/Doedal/train/꼬임/102.png',
#  'drive/MyDrive/Doedal/train/꼬임/126.png',
#  'drive/MyDrive/Doedal/train/꼬임/6.png',
#  'drive/MyDrive/Doedal/train/꼬임/69.png',
#  'drive/MyDrive/Doedal/train/꼬임/114.png',
#  'drive/MyDrive/Doedal/train/꼬임/35.png',
#  'drive/MyDrive/Doedal/train/꼬임/174.png',
#  'drive/MyDrive/Doedal/train/꼬임/58.png',
#  'drive/MyDrive/Doedal/train/꼬임/19.png',
#  'drive/MyDrive/Doedal/train/꼬임/200.png',
#  'drive/MyDrive/Doedal/train/꼬임/57.png',
#  'drive/MyDrive/Doedal/train/꼬임/113.png',
#  'drive/MyDrive/Doedal/train/꼬임/88.png',
#  'drive/MyDrive/Doedal/train/꼬임/105.png',
#  'drive/MyDrive/Doedal/train/꼬임/180.png',
#  'drive/MyDrive/Doedal/train/꼬임/196.png',
#  'drive/MyDrive/Doedal/train/꼬임/112.png',
#  'drive/MyDrive/Doedal/train/꼬임/43.png',
#  'drive/MyDrive/Doedal/train/꼬임/125.png',
#  'drive/MyDrive/Doedal/train/꼬임/103.png',
#  'drive/MyDrive/Doedal/train/꼬임/117.png',
#  'drive/MyDrive/Doedal/train/꼬임/178.png',
#  'drive/MyDrive/Doedal/train/꼬임/32.png',
#  'drive/MyDrive/Doedal/train/꼬임/163.png',
#  'drive/MyDrive/Doedal/train/꼬임/89.png',
#  'drive/MyDrive/Doedal/train/꼬임/71.png',
#  'drive/MyDrive/Doedal/train/꼬임/52.png',
#  'drive/MyDrive/Doedal/train/꼬임/45.png',
#  'drive/MyDrive/Doedal/train/꼬임/187.png',
#  'drive/MyDrive/Doedal/train/꼬임/42.png',
#  'drive/MyDrive/Doedal/train/꼬임/164.png',
#  'drive/MyDrive/Doedal/train/꼬임/201.png',
#  'drive/MyDrive/Doedal/train/꼬임/97.png',
#  'drive/MyDrive/Doedal/train/꼬임/119.png',
#  'drive/MyDrive/Doedal/train/꼬임/192.png',
#  'drive/MyDrive/Doedal/train/꼬임/68.png',
#  'drive/MyDrive/Doedal/train/꼬임/87.png',
#  'drive/MyDrive/Doedal/train/꼬임/108.png',
#  'drive/MyDrive/Doedal/train/꼬임/79.png',
#  'drive/MyDrive/Doedal/train/꼬임/124.png',
#  'drive/MyDrive/Doedal/train/꼬임/137.png',
#  'drive/MyDrive/Doedal/train/꼬임/51.png',
#  'drive/MyDrive/Doedal/train/꼬임/111.png',
#  'drive/MyDrive/Doedal/train/꼬임/202.png',
#  'drive/MyDrive/Doedal/train/꼬임/199.png',
#  'drive/MyDrive/Doedal/train/꼬임/185.png',
#  'drive/MyDrive/Doedal/train/꼬임/134.png',
#  'drive/MyDrive/Doedal/train/꼬임/20.png',
#  'drive/MyDrive/Doedal/train/꼬임/197.png',
#  'drive/MyDrive/Doedal/train/꼬임/207.png',
#  'drive/MyDrive/Doedal/train/꼬임/101.png',
#  'drive/MyDrive/Doedal/train/꼬임/176.png',
#  'drive/MyDrive/Doedal/train/꼬임/81.png',
#  'drive/MyDrive/Doedal/train/꼬임/23.png',
#  'drive/MyDrive/Doedal/train/꼬임/181.png',
#  'drive/MyDrive/Doedal/train/꼬임/15.png',
#  'drive/MyDrive/Doedal/train/꼬임/188.png',
#  'drive/MyDrive/Doedal/train/꼬임/205.png',
#  'drive/MyDrive/Doedal/train/꼬임/149.png',
#  'drive/MyDrive/Doedal/train/꼬임/98.png',
#  'drive/MyDrive/Doedal/train/꼬임/179.png',
#  'drive/MyDrive/Doedal/train/꼬임/135.png',
#  'drive/MyDrive/Doedal/train/꼬임/99.png',
#  'drive/MyDrive/Doedal/train/꼬임/133.png',
#  'drive/MyDrive/Doedal/train/꼬임/83.png',
#  'drive/MyDrive/Doedal/train/꼬임/93.png',
#  'drive/MyDrive/Doedal/train/꼬임/131.png',
#  'drive/MyDrive/Doedal/train/꼬임/206.png',
#  'drive/MyDrive/Doedal/train/꼬임/106.png',
#  'drive/MyDrive/Doedal/train/꼬임/115.png',
#  'drive/MyDrive/Doedal/train/꼬임/130.png',
#  'drive/MyDrive/Doedal/train/꼬임/203.png',
#  'drive/MyDrive/Doedal/train/꼬임/7.png',
#  'drive/MyDrive/Doedal/train/꼬임/9.png',
#  'drive/MyDrive/Doedal/train/꼬임/141.png',
#  'drive/MyDrive/Doedal/train/꼬임/204.png',
#  'drive/MyDrive/Doedal/train/꼬임/118.png',
#  'drive/MyDrive/Doedal/train/꼬임/123.png',
#  'drive/MyDrive/Doedal/train/꼬임/140.png',
#  'drive/MyDrive/Doedal/train/꼬임/129.png',
#  'drive/MyDrive/Doedal/train/꼬임/148.png',
#  'drive/MyDrive/Doedal/train/꼬임/162.png',
#  'drive/MyDrive/Doedal/train/꼬임/86.png',
#  'drive/MyDrive/Doedal/train/꼬임/136.png',
#  'drive/MyDrive/Doedal/train/꼬임/182.png',
#  'drive/MyDrive/Doedal/train/꼬임/96.png',
#  'drive/MyDrive/Doedal/train/꼬임/146.png',
#  'drive/MyDrive/Doedal/train/꼬임/190.png',
#  'drive/MyDrive/Doedal/train/꼬임/173.png',
#  'drive/MyDrive/Doedal/train/꼬임/3.png',
#  'drive/MyDrive/Doedal/train/꼬임/80.png',
#  'drive/MyDrive/Doedal/train/꼬임/209.png',
#  'drive/MyDrive/Doedal/train/꼬임/55.png',
#  'drive/MyDrive/Doedal/train/꼬임/74.png',
#  'drive/MyDrive/Doedal/train/꼬임/73.png',
#  'drive/MyDrive/Doedal/train/꼬임/67.png',
#  'drive/MyDrive/Doedal/train/꼬임/195.png',
#  'drive/MyDrive/Doedal/train/꼬임/34.png',
#  'drive/MyDrive/Doedal/train/꼬임/155.png',
#  'drive/MyDrive/Doedal/train/꼬임/18.png',
#  'drive/MyDrive/Doedal/train/꼬임/53.png',
#  'drive/MyDrive/Doedal/train/꼬임/158.png',
#  'drive/MyDrive/Doedal/train/꼬임/77.png',
#  'drive/MyDrive/Doedal/train/꼬임/151.png',
#  'drive/MyDrive/Doedal/train/꼬임/94.png',
#  'drive/MyDrive/Doedal/train/꼬임/177.png',
#  'drive/MyDrive/Doedal/train/꼬임/127.png',
#  'drive/MyDrive/Doedal/train/꼬임/36.png',
#  'drive/MyDrive/Doedal/train/꼬임/63.png',
#  'drive/MyDrive/Doedal/train/꼬임/128.png',
#  'drive/MyDrive/Doedal/train/꼬임/26.png',
#  'drive/MyDrive/Doedal/train/꼬임/161.png',
#  'drive/MyDrive/Doedal/train/꼬임/41.png',
#  'drive/MyDrive/Doedal/train/울음/4.png',
#  'drive/MyDrive/Doedal/train/울음/17.png',
#  'drive/MyDrive/Doedal/train/울음/16.png',
#  'drive/MyDrive/Doedal/train/울음/19.png',
#  'drive/MyDrive/Doedal/train/울음/1.png',
#  'drive/MyDrive/Doedal/train/울음/18.png',
#  'drive/MyDrive/Doedal/train/울음/5.png',
#  'drive/MyDrive/Doedal/train/울음/20.png',
#  'drive/MyDrive/Doedal/train/울음/21.png',
#  'drive/MyDrive/Doedal/train/울음/2.png',
#  'drive/MyDrive/Doedal/train/울음/12.png',
#  'drive/MyDrive/Doedal/train/울음/14.png',
#  'drive/MyDrive/Doedal/train/울음/15.png',
#  'drive/MyDrive/Doedal/train/울음/0.png',
#  'drive/MyDrive/Doedal/train/울음/6.png',
#  'drive/MyDrive/Doedal/train/울음/8.png',
#  'drive/MyDrive/Doedal/train/울음/7.png',
#  'drive/MyDrive/Doedal/train/울음/10.png',
#  'drive/MyDrive/Doedal/train/울음/3.png',
#  'drive/MyDrive/Doedal/train/울음/11.png',
#  'drive/MyDrive/Doedal/train/울음/13.png',
#  'drive/MyDrive/Doedal/train/울음/9.png',
#  'drive/MyDrive/Doedal/train/오타공/97.png',
#  'drive/MyDrive/Doedal/train/오타공/91.png',
#  'drive/MyDrive/Doedal/train/오타공/140.png',
#  'drive/MyDrive/Doedal/train/오타공/141.png',
#  'drive/MyDrive/Doedal/train/오타공/92.png',
#  'drive/MyDrive/Doedal/train/오타공/28.png',
#  'drive/MyDrive/Doedal/train/오타공/11.png',
#  'drive/MyDrive/Doedal/train/오타공/21.png',
#  'drive/MyDrive/Doedal/train/오타공/68.png',
#  'drive/MyDrive/Doedal/train/오타공/4.png',
#  'drive/MyDrive/Doedal/train/오타공/137.png',
png',
#  'drive/MyDrive/Doedal/train/몰딩수정/103.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/120.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/53.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/26.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/45.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/95.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/82.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/52.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/128.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/129.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/7.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/21.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/19.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/59.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/91.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/32.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/5.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/87.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/106.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/119.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/34.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/31.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/115.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/54.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/57.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/29.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/122.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/70.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/125.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/114.png',
#  'drive/MyDrive/Doedal/train/몰딩수정/105.png',
#  'drive/MyDrive/Doedal/train/면불량/97.png',
#  'drive/MyDrive/Doedal/train/면불량/88.png',
#  'drive/MyDrive/Doedal/train/면불량/65.png',
#  'drive/MyDrive/Doedal/train/면불량/81.png',
#  'drive/MyDrive/Doedal/train/면불량/3.png',
#  'drive/MyDrive/Doedal/train/면불량/77.png',
#  'drive/MyDrive/Doedal/train/면불량/71.png',
#  'drive/MyDrive/Doedal/train/면불량/12.png',
#  'drive/MyDrive/Doedal/train/면불량/41.png',
#  'drive/MyDrive/Doedal/train/면불량/10.png',
#  'drive/MyDrive/Doedal/train/면불량/2.png',
#  'drive/MyDrive/Doedal/train/면불량/78.png',
#  'drive/MyDrive/Doedal/train/면불량/43.png',
#  'drive/MyDrive/Doedal/train/면불량/21.png',
#  'drive/MyDrive/Doedal/train/면불량/66.png',
#  'drive/MyDrive/Doedal/train/면불량/93.png',
#  'drive/MyDrive/Doedal/train/면불량/62.png',
#  'drive/MyDrive/Doedal/train/면불량/37.png',
#  'drive/MyDrive/Doedal/train/면불량/53.png',
#  'drive/MyDrive/Doedal/train/면불량/9.png',
#  'drive/MyDrive/Doedal/train/면불량/54.png',
#  'drive/MyDrive/Doedal/train/면불량/79.png',
#  'drive/MyDrive/Doedal/train/면불량/18.png',
#  'drive/MyDrive/Doedal/train/면불량/94.png',
#  'drive/MyDrive/Doedal/train/면불량/75.png',
#  'drive/MyDrive/Doedal/train/면불량/4.png',
#  'drive/MyDrive/Doedal/train/면불량/44.png',
#  'drive/MyDrive/Doedal/train/면불량/51.png',
#  'drive/MyDrive/Doedal/train/면불량/39.png',
#  'drive/MyDrive/Doedal/train/면불량/50.png',
#  'drive/MyDrive/Doedal/train/면불량/30.png',
#  'drive/MyDrive/Doedal/train/면불량/84.png',
#  'drive/MyDrive/Doedal/train/면불량/25.png',
#  'drive/MyDrive/Doedal/train/면불량/35.png',
#  'drive/MyDrive/Doedal/train/면불량/27.png',
#  'drive/MyDrive/Doedal/train/면불량/15.png',
#  'drive/MyDrive/Doedal/train/면불량/63.png',
#  'drive/MyDrive/Doedal/train/면불량/7.png',
#  'drive/MyDrive/Doedal/train/면불량/34.png',
#  'drive/MyDrive/Doedal/train/면불량/32.png',
#  'drive/MyDrive/Doedal/train/면불량/67.png',
#  'drive/MyDrive/Doedal/train/면불량/31.png',
#  'drive/MyDrive/Doedal/train/면불량/47.png',
#  'drive/MyDrive/Doedal/train/면불량/8.png',
#  'drive/MyDrive/Doedal/train/면불량/38.png',
#  'drive/MyDrive/Doedal/train/면불량/72.png',
#  'drive/MyDrive/Doedal/train/면불량/6.png',
#  'drive/MyDrive/Doedal/train/면불량/19.png',
#  'drive/MyDrive/Doedal/train/면불량/52.png',
#  'drive/MyDrive/Doedal/train/면불량/59.png',
#  'drive/MyDrive/Doedal/train/면불량/49.png',
#  'drive/MyDrive/Doedal/train/면불량/68.png',
#  'drive/MyDrive/Doedal/train/면불량/13.png',
#  'drive/MyDrive/Doedal/train/면불량/33.png',
#  'drive/MyDrive/Doedal/train/면불량/74.png',
#  'drive/MyDrive/Doedal/train/면불량/0.png',
#  'drive/MyDrive/Doedal/train/면불량/16.png',
#  'drive/MyDrive/Doedal/train/면불량/45.png',
#  'drive/MyDrive/Doedal/train/면불량/56.png',
#  'drive/MyDrive/Doedal/train/면불량/89.png',
#  'drive/MyDrive/Doedal/train/면불량/95.png',
#  'drive/MyDrive/Doedal/train/면불량/70.png',
#  'drive/MyDrive/Doedal/train/면불량/92.png',
#  'drive/MyDrive/Doedal/train/면불량/82.png',
#  'drive/MyDrive/Doedal/train/면불량/60.png',
#  'drive/MyDrive/Doedal/train/면불량/23.png',
#  'drive/MyDrive/Doedal/train/면불량/5.png',
#  'drive/MyDrive/Doedal/train/면불량/80.png',
#  'drive/MyDrive/Doedal/train/면불량/98.png',
#  'drive/MyDrive/Doedal/train/면불량/36.png',
#  'drive/MyDrive/Doedal/train/면불량/24.png',
#  'drive/MyDrive/Doedal/train/면불량/42.png',
#  'drive/MyDrive/Doedal/train/면불량/57.png',
#  'drive/MyDrive/Doedal/train/면불량/48.png',
#  'drive/MyDrive/Doedal/train/면불량/1.png',
#  'drive/MyDrive/Doedal/train/면불량/64.png',
#  'drive/MyDrive/Doedal/train/면불량/83.png',
#  'drive/MyDrive/Doedal/train/면불량/85.png',
#  'drive/MyDrive/Doedal/train/면불량/46.png',
#  'drive/MyDrive/Doedal/train/면불량/17.png',
#  'drive/MyDrive/Doedal/train/면불량/11.png',
#  'drive/MyDrive/Doedal/train/면불량/55.png',
#  'drive/MyDrive/Doedal/train/면불량/73.png',
#  'drive/MyDrive/Doedal/train/면불량/86.png',
#  'drive/MyDrive/Doedal/train/면불량/90.png',
#  'drive/MyDrive/Doedal/train/면불량/61.png',
#  'drive/MyDrive/Doedal/train/면불량/96.png',
#  'drive/MyDrive/Doedal/train/면불량/58.png',
#  'drive/MyDrive/Doedal/train/면불량/28.png',
#  'drive/MyDrive/Doedal/train/면불량/87.png',
#  'drive/MyDrive/Doedal/train/면불량/20.png',
#  'drive/MyDrive/Doedal/train/면불량/91.png',
#  'drive/MyDrive/Doedal/train/면불량/29.png',
#  'drive/MyDrive/Doedal/train/면불량/14.png',
#  'drive/MyDrive/Doedal/train/면불량/26.png',
#  'drive/MyDrive/Doedal/train/면불량/22.png',
#  'drive/MyDrive/Doedal/train/면불량/40.png',
#  'drive/MyDrive/Doedal/train/면불량/76.png',
#  'drive/MyDrive/Doedal/train/면불량/69.png',
#  'drive/MyDrive/Doedal/train/창틀,문틀수정/4.png',
#  'drive/MyDrive/Doedal/train/창틀,문틀수정/2.png',
#  ...]

# %%
df = pd.DataFrame(columns=['img_path', 'label'])
df['img_path'] = all_img_list
df['label'] = df['img_path'].apply(lambda x : str(x).split('/')[4])

# %%
df['label'].value_counts()
# Out:
# 훼손                 1405
# 오염                  595
# 걸레받이수정        307
# 꼬임                  210
# 터짐                  162
# 곰팡이               145
# 오타공                142
# 몰딩수정            130
# 면불량               99
# 석고수정              57
# 들뜸                  54
# 피스                    51
# 창틀,문틀수정      27
# 울음                  22
# 이음부불량           17
# 녹오염                14
# 가구수정               12
# 틈새과다                5
# 반점                   3
# Name: label, dtype: int64

# %%
# 라벨 인코더 생성
encoder = LabelEncoder()

# X_train데이터를 이용 피팅하고 라벨숫자로 변환
encoder.fit(df['label'])
new_label = encoder.transform(df['label'])

# %%
new_label
# Out:
# array([ 1,  1,  1, ..., 16, 16, 16])

# %%
df['label'] = new_label
df
# Out:
#                                                img_path  label
# 0     drive/MyDrive/Doedal/train/걸레받이수정/111...      1
# 1     drive/MyDrive/Doedal/train/걸레받이수정/11.png      1
# 2     drive/MyDrive/Doedal/train/걸레받이수정/175...      1
# 3     drive/MyDrive/Doedal/train/걸레받이수정/178...      1
# 4     drive/MyDrive/Doedal/train/걸레받이수정/20.png      1
# ...                                                 ...    ...
# 3452         drive/MyDrive/Doedal/train/틈새과다/1.png     16
# 3453         drive/MyDrive/Doedal/train/틈새과다/4.png     16
# 3454         drive/MyDrive/Doedal/train/틈새과다/3.png     16
# 3455         drive/MyDrive/Doedal/train/틈새과다/2.png     16
# 3456         drive/MyDrive/Doedal/train/틈새과다/0.png     16
#
# [3457 rows x 2 columns]

# %%
# train 7 : val 3 
train, val, _, _ = train_test_split(df, df['label'], test_size=0.3, stratify=df['label'], random_state=CFG['SEED'])

# %% [markdown]
# ## Label-Encoding

# %%
le = preprocessing.LabelEncoder()
train['label'] = le.fit_transform(train['label'])
val['label'] = le.transform(val['label'])

# %%
train['label']
# Out:
# 3064    18
# 1831    18
# 2063    18
# 2341    18
# 2047    18
#         ..
# 2687    18
# 1495    10
# 980      6
# 2509    18
# 833      7
# Name: label, Length: 2419, dtype: int64

# %%
val['label']
# Out:
# 121      1
# 2893    18
# 0        1
# 1593    10
# 3095    18
#         ..
# 1184    15
# 1393    10
# 2060    18
# 545      3
# 1947    18
# Name: label, Length: 1038, dtype: int64

# %% [markdown]
# ## CustomDataset

# %%
class CustomDataset(Dataset):
    def __init__(self, img_path_list, label_list, transforms=None):
        self.img_path_list = img_path_list
        self.label_list = label_list
        self.transforms = transforms
        
    def __getitem__(self, index):
        img_path = self.img_path_list[index]
        
        image = cv2.imread(img_path)
        
        if self.transforms is not None:
            image = self.transforms(image=image)['image']
        
        if self.label_list is not None:
            label = self.label_list[index]
            return image, label
        else:
            return image
        
    def __len__(self):
        return len(self.img_path_list)

# %%
train_transform = A.Compose([
                            A.Resize(CFG['IMG_SIZE'],CFG['IMG_SIZE']),
                            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            A.HorizontalFlip(p=0.5),
                            #A.VerticalFlip(p=0.5),
                            #A.RandomBrightnessContrast(p=0.2),
                            ToTensorV2()
                            ])

test_transform = A.Compose([
                            A.Resize(CFG['IMG_SIZE'],CFG['IMG_SIZE']),
                            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), max_pixel_value=255.0, always_apply=False, p=1.0),
                            #A.HorizontalFlip(p=0.3),
                            #A.RandomBrightnessContrast(p=0.2),
                            #A.VerticalFlip(p=0.5),
                            ToTensorV2()
                            ])

# %%
train_dataset = CustomDataset(train['img_path'].values, train['label'].values, train_transform)
train_loader = DataLoader(train_dataset, batch_size = CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

val_dataset = CustomDataset(val['img_path'].values, val['label'].values, test_transform)
val_loader = DataLoader(val_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %% [markdown]
# ## Model Define

# %%
class BaseModel(nn.Module):
    def __init__(self, num_classes=len(le.classes_)):
        super(BaseModel, self).__init__()
        self.backbone = models.efficientnet_b0(pretrained=True)
        self.classifier = nn.Linear(1000, num_classes)
        
    def forward(self, x):
        x = self.backbone(x)
        x = self.classifier(x)
        return x

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

class FocalLoss(nn.Module):
    def __init__(self, gamma=0, alpha=None, size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        if isinstance(alpha,(float,int)): self.alpha = torch.Tensor([alpha]*19)
        self.alpha[18] = 1-alpha
        if isinstance(alpha,list): self.alpha = torch.Tensor(alpha)
        self.size_average = size_average

    def forward(self, input, target):
        if input.dim()>2:
            input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
            input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
            input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
        target = target.view(-1,1)

        logpt = F.log_softmax(input)
        logpt = logpt.gather(1,target)
        logpt = logpt.view(-1)
        pt = Variable(logpt.data.exp())

        if self.alpha is not None:
            if self.alpha.type()!=input.data.type():
                self.alpha = self.alpha.type_as(input.data)
            at = self.alpha.gather(0,target.data.view(-1))
            logpt = logpt * at

        loss = -1 * (1-pt)**self.gamma * logpt
        if self.size_average: return loss.mean()
        else: return loss.sum()

# %% [markdown]
# ## Train

# %%
def train(model, optimizer, train_loader, val_loader, scheduler, device):
    model.to(device)
    #criterion = nn.CrossEntropyLoss().to(device)
    criterion = FocalLoss(gamma=2, alpha=0.25)
    
    best_score = 0
    best_model = None
    
    for epoch in range(1, CFG['EPOCHS']+1):
        model.train()
        train_loss = []
        for imgs, labels in tqdm(iter(train_loader)):
            imgs = imgs.float().to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            
            output = model(imgs)
            loss = criterion(output, labels)
            
            loss.backward()
            optimizer.step()
            
            train_loss.append(loss.item())
                    
        _val_loss, _val_score = validation(model, criterion, val_loader, device)
        _train_loss = np.mean(train_loss)
        print(f'Epoch [{epoch}], Train Loss : [{_train_loss:.5f}] Val Loss : [{_val_loss:.5f}] Val Weighted F1 Score : [{_val_score:.5f}]')
       
        if scheduler is not None:
            scheduler.step(_val_score)
            
        if best_score < _val_score:
            best_score = _val_score
            best_model = model
    
    return best_model

# %%
def validation(model, criterion, val_loader, device):
    model.eval()
    val_loss = []
    preds, true_labels = [], []

    with torch.no_grad():
        for imgs, labels in tqdm(iter(val_loader)):
            imgs = imgs.float().to(device)
            labels = labels.to(device)
            
            pred = model(imgs)
            
            loss = criterion(pred, labels)
            
            preds += pred.argmax(1).detach().cpu().numpy().tolist()
            true_labels += labels.detach().cpu().numpy().tolist()
            
            val_loss.append(loss.item())
        
        _val_loss = np.mean(val_loss)
        _val_score = f1_score(true_labels, preds, average='weighted')
    
    return _val_loss, _val_score

# %%
model = BaseModel()
model.eval()
optimizer = torch.optim.Adam(params = model.parameters(), lr = CFG["LEARNING_RATE"])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2, threshold_mode='abs', min_lr=1e-8, verbose=True)

infer_model = train(model, optimizer, train_loader, val_loader, scheduler, device)
# Out:
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [1], Train Loss : [7402.78915] Val Loss : [1422.94489] Val Weighted F1 Score : [0.23495]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [2], Train Loss : [447.57364] Val Loss : [139840.03175] Val Weighted F1 Score : [0.23518]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [3], Train Loss : [179.68749] Val Loss : [2032458.65908] Val Weighted F1 Score : [0.23343]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [4], Train Loss : [88.94161] Val Loss : [65.78217] Val Weighted F1 Score : [0.23502]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [5], Train Loss : [96.44623] Val Loss : [80.46481] Val Weighted F1 Score : [0.23502]
# Epoch 00005: reducing learning rate of group 0 to 2.5000e-01.
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [6], Train Loss : [49.58951] Val Loss : [27.50247] Val Weighted F1 Score : [0.04371]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [7], Train Loss : [31.74575] Val Loss : [29.18474] Val Weighted F1 Score : [0.23502]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [8], Train Loss : [26.88165] Val Loss : [18.96972] Val Weighted F1 Score : [0.23502]
# Epoch 00008: reducing learning rate of group 0 to 1.2500e-01.
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [9], Train Loss : [21.74815] Val Loss : [11.60662] Val Weighted F1 Score : [0.23502]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [10], Train Loss : [19.17362] Val Loss : [15.77347] Val Weighted F1 Score : [0.23502]
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [11], Train Loss : [18.04766] Val Loss : [12.13048] Val Weighted F1 Score : [0.03475]
# Epoch 00011: reducing learning rate of group 0 to 6.2500e-02.
#   0%|          | 0/76 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
# Epoch [12], Train Loss : [15.49423] Val Loss : [11.91047] Val Weighted F1 Score : [0.23502]
#   0%|          | 0/76 [00:00<?, ?it/s]

# %% [markdown]
# ## Inference

# %%
test = pd.read_csv('drive/MyDrive/Doedal/test.csv')
test['img_path'] = test['img_path'].apply(lambda x: x.replace('./', 'drive/MyDrive/Doedal/', 1))

# %%
test
# Out:
#            id                           img_path
# 0    TEST_000  drive/MyDrive/Doedal/test/000.png
# 1    TEST_001  drive/MyDrive/Doedal/test/001.png
# 2    TEST_002  drive/MyDrive/Doedal/test/002.png
# 3    TEST_003  drive/MyDrive/Doedal/test/003.png
# 4    TEST_004  drive/MyDrive/Doedal/test/004.png
# ..        ...                                ...
# 787  TEST_787  drive/MyDrive/Doedal/test/787.png
# 788  TEST_788  drive/MyDrive/Doedal/test/788.png
# 789  TEST_789  drive/MyDrive/Doedal/test/789.png
# 790  TEST_790  drive/MyDrive/Doedal/test/790.png
# 791  TEST_791  drive/MyDrive/Doedal/test/791.png
#
# [792 rows x 2 columns]

# %%
test_dataset = CustomDataset(test['img_path'].values, None, test_transform)
test_loader = DataLoader(test_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=0)

# %%
def inference(model, test_loader, device):
    model.eval()
    preds = []
    with torch.no_grad():
        for imgs in tqdm(iter(test_loader)):
            imgs = imgs.float().to(device)
            
            pred = model(imgs)
            
            preds += pred.argmax(1).detach().cpu().numpy().tolist()
    
    preds = le.inverse_transform(preds)
    return preds

# %%
preds = inference(infer_model, test_loader, device)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
preds
# Out:
# array([18, 10, 18, 18, 10, 18, 10, 18, 18, 11,  7, 11, 10, 10, 18, 15,  9,
#         1, 10, 18, 14, 18, 18, 15, 18, 18, 10,  2, 18, 18, 10, 18, 18, 10,
#        10, 18, 18, 18, 11, 18, 10,  5, 18, 15, 18,  6, 10, 18, 10, 10, 18,
#        18, 10, 18, 18, 18, 18, 10, 18, 10, 11,  7, 18, 10, 18, 18, 10, 10,
#        18, 15, 10, 10, 10,  4, 18, 18, 18, 10, 18, 15, 10, 18, 18, 11, 15,
#        18, 18, 15, 18, 18, 10, 18, 18, 10, 18, 18, 18, 11, 11, 18, 17, 18,
#        18, 15, 18, 18,  0, 18, 18, 18, 15, 18, 18, 18, 10, 18, 18, 10, 15,
#        18, 18, 10, 18,  2, 18, 17, 18, 18, 18, 10, 18, 18,  9, 10, 11, 10,
#        15, 18, 18, 10, 11, 18, 10, 10, 11, 18, 18, 18, 18, 18, 18, 18, 18,
#        18, 18, 13, 10, 10, 18, 18, 10, 10, 18, 18, 18, 10, 18, 18, 18, 18,
#        18, 18, 18, 10, 10,  3, 10,  9, 18, 14, 18,  2, 11,  3, 18, 18,  3,
#        18,  3,  3, 18, 18, 18, 18, 18,  2, 18, 13, 18,  7, 18,  3, 10,  5,
#         3,  3, 18, 18,  3, 18,  3, 18, 18, 18, 10,  3, 18, 18,  6, 18, 10,
#        18, 15,  2, 18, 10, 10, 10, 10, 18, 10, 10, 10, 18, 15, 18, 16, 18,
#         6, 18, 10, 18, 15, 18, 15, 18, 18, 18, 18, 10, 10,  9, 18, 18,  1,
#        18,  4,  7, 10,  7, 11, 18, 18, 18, 18,  7, 18,  3, 10, 10, 18,  1,
#        18, 10, 18, 15,  3,  3, 10,  7, 18, 10,  4, 10, 10, 15, 18, 10, 18,
#        10, 10, 15, 18, 18, 10, 18, 18, 11, 10, 10, 18, 10,  2, 18, 18, 18,
#        18,  6, 18, 10, 18, 17, 17, 10, 18, 10, 18, 18, 18,  3, 15,  2,  9,
#        10, 10,  6, 10, 15, 16, 18, 18, 10, 10, 18, 10, 18, 18, 18, 18, 10,
#        11, 18, 18, 17, 18, 18, 15, 13, 10,  0, 18, 18, 15,  3, 18, 10, 18,
#         3,  1, 10, 10, 10,  1, 18, 10, 10, 18, 18,  2, 18, 17, 15, 18, 18,
#        '훼손', '훼손', '오염', '오염', '훼손', '훼손', '훼손',
#        '오타공', '훼손', '오염', '들뜸', '훼손', '터짐', '훼손',
#        '면불량', '오염', '훼손', '오염', '오염', '훼손', '훼손',
#        '오염', '훼손', '훼손', '훼손', '훼손', '오염', '훼손',
#        '오염', '오타공', '몰딩수정', '훼손', '오염', '훼손',
#        '훼손', '오염', '오염', '훼손', '터짐', '오염', '오염',
#        '오염', '녹오염', '훼손', '훼손', '훼손', '오염', '훼손',
#        '터짐', '오염', '훼손', '훼손', '오타공', '터짐', '훼손',
#        '훼손', '터짐', '훼손', '훼손', '오염', '훼손', '훼손',
#        '오염', '훼손', '훼손', '훼손', '오타공', '오타공', '훼손',
#        '피스', '훼손', '훼손', '터짐', '훼손', '훼손', '가구수정',
#        '훼손', '훼손', '훼손', '터짐', '훼손', '훼손', '훼손',
#        '오염', '훼손', '훼손', '오염', '터짐', '훼손', '훼손',
#        '오염', '훼손', '곰팡이', '훼손', '피스', '훼손', '훼손',
#        '훼손', '오염', '훼손', '훼손', '석고수정', '오염',
#        '오타공', '오염', '터짐', '훼손', '훼손', '오염', '오타공',
#        '훼손', '오염', '오염', '오타공', '훼손', '훼손', '훼손',
#        '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손',
#        '이음부불량', '오염', '오염', '훼손', '훼손', '오염',
#        '오염', '훼손', '훼손', '훼손', '오염', '훼손', '훼손',
#        '훼손', '훼손', '훼손', '훼손', '훼손', '오염', '오염',
#        '꼬임', '오염', '석고수정', '훼손', '창틀,문틀수정',
#        '훼손', '곰팡이', '오타공', '꼬임', '훼손', '훼손', '꼬임',
#        '훼손', '꼬임', '꼬임', '훼손', '훼손', '훼손', '훼손',
#        '훼손', '곰팡이', '훼손', '이음부불량', '훼손',
#        '몰딩수정', '훼손', '꼬임', '오염', '들뜸', '꼬임',
#        '꼬임', '훼손', '훼손', '꼬임', '훼손', '꼬임', '훼손',
#        '훼손', '훼손', '오염', '꼬임', '훼손', '훼손', '면불량',
#        '훼손', '오염', '훼손', '터짐', '곰팡이', '훼손', '오염',
#        '오염', '오염', '오염', '훼손', '오염', '오염', '오염',
#        '훼손', '터짐', '훼손', '틈새과다', '훼손', '면불량',
#        '훼손', '오염', '훼손', '터짐', '훼손', '터짐', '훼손',
#        '훼손', '훼손', '훼손', '오염', '오염', '석고수정', '훼손',
#        '훼손', '걸레받이수정', '훼손', '녹오염', '몰딩수정',
#        '오염', '몰딩수정', '오타공', '훼손', '훼손', '훼손',
#        '훼손', '몰딩수정', '훼손', '꼬임', '오염', '오염',
#        '훼손', '걸레받이수정', '훼손', '오염', '훼손', '터짐',
#        '꼬임', '꼬임', '오염', '몰딩수정', '훼손', '오염',
#        '녹오염', '오염', '오염', '터짐', '훼손', '오염', '훼손',
#        '오염', '오염', '터짐', '훼손', '훼손', '오염', '훼손',
#        '훼손', '오타공', '오염', '오염', '훼손', '오염', '곰팡이',
#        '훼손', '훼손', '훼손', '훼손', '면불량', '훼손', '오염',
#        '훼손', '피스', '피스', '오염', '훼손', '오염', '훼손',
#        '훼손', '훼손', '꼬임', '터짐', '곰팡이', '석고수정',
#        '오염', '오염', '면불량', '오염', '터짐', '틈새과다',
#        '훼손', '훼손', '오염', '오염', '훼손', '오염', '훼손',
#        '훼손', '훼손', '훼손', '오염', '오타공', '훼손', '훼손',
#        '피스', '훼손', '훼손', '터짐', '이음부불량', '오염',
#        '가구수정', '훼손', '훼손', '터짐', '꼬임', '훼손', '오염',
#        '훼손', '꼬임', '걸레받이수정', '오염', '오염', '오염',
#        '걸레받이수정', '훼손', '오염', '오염', '훼손', '훼손',
#        '곰팡이', '훼손', '피스', '터짐', '훼손', '훼손',
#        '석고수정', '오염', '훼손', '훼손', '훼손', '오염', '오염',
#        '훼손', '오염', '훼손', '이음부불량', '녹오염', '훼손',
#        '곰팡이', '훼손', '훼손', '훼손', '오염', '훼손', '오염',
#        '면불량', '오염', '오염', '터짐', '훼손', '오염', '훼손',
#        '터짐', '훼손', '훼손', '꼬임', '오염', '오염', '훼손',
#        '훼손', '면불량', '면불량', '훼손', '오염', '곰팡이',
#        '오염', '오염', '오염', '오염', '몰딩수정', '훼손',
#        '훼손', '훼손', '몰딩수정', '오염', '오염', '훼손',
#        '훼손', '훼손', '가구수정', '훼손', '오염', '훼손',
#        '창틀,문틀수정', '오염', '피스', '가구수정', '훼손',
#        '터짐', '터짐', '오염', '훼손', '오염', '훼손', '오염',
#        '훼손', '터짐', '훼손', '훼손', '오염', '오염', '오염',
#        '오염', '오염', '걸레받이수정', '오염', '이음부불량',
#        '오염', '녹오염', '걸레받이수정', '면불량', '오염',
#        '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손',
#        '곰팡이', '훼손', '곰팡이', '훼손', '터짐', '오염',
#        '훼손', '훼손', '훼손', '훼손', '터짐', '터짐', '훼손',
#        '꼬임', '오염', '꼬임', '오염', '훼손', '훼손', '훼손',
#        '곰팡이', '훼손', '훼손', '면불량', '오염', '훼손',
#        '가구수정', '면불량', '훼손', '꼬임', '터짐', '오염',
#        '훼손', '석고수정', '오염', '석고수정', '오염', '오염',
#        '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '훼손',
#        '면불량', '꼬임', '오염', '훼손', '훼손', '울음',
#        '오타공', '터짐', '훼손', '가구수정', '꼬임', '터짐',
#        '터짐', '훼손', '훼손', '훼손', '면불량', '훼손', '오염',
#        '꼬임', '훼손', '울음', '오염', '오염', '오염',
#        '석고수정', '오염', '오염', '훼손', '오염', '훼손', '꼬임',
#        '훼손', '틈새과다', '오염', '오염', '오염', '오염', '오염',
#        '오타공', '훼손', '터짐', '들뜸', '면불량', '훼손',
#        '면불량', '훼손', '석고수정', '훼손', '훼손', '오염',
#        '훼손', '오염', '터짐', '훼손', '훼손', '터짐', '면불량',
#        '오염', '훼손', '오염', '오염', '훼손', '훼손', '훼손',
#        '오염', '오염', '오염', '훼손', '훼손', '훼손', '훼손',
#        '훼손', '오염', '오타공', '면불량', '오염',
#        '걸레받이수정', '훼손', '훼손', '훼손', '훼손', '오염',
#        '훼손', '오염', '곰팡이', '훼손', '훼손', '오염', '오염',
#        '훼손', '들뜸', '훼손', '훼손', '훼손', '오염', '피스',
#        '면불량', '훼손', '터짐', '훼손', '오타공', '곰팡이',
#        '오타공', '훼손', '터짐', '훼손', '오염', '훼손', '훼손',
#        '오염', '훼손', '오염', '터짐', '면불량', '오염', '훼손',
#        '훼손', '꼬임', '오염', '들뜸', '훼손', '훼손', '훼손',
#        '이음부불량', '터짐', '터짐', '오염', '걸레받이수정',
#        '훼손', '훼손', '오염', '곰팡이', '오염', '터짐', '훼손',
#        '면불량', '훼손', '훼손', '터짐', '녹오염', '훼손',
#        '곰팡이', '훼손', '오염', '터짐', '오타공', '오염', '오염',
#        '훼손', '훼손', '훼손', '훼손', '꼬임', '훼손', '오염',
#        '훼손', '훼손', '훼손', '오염', '오염', '훼손', '오염',
#        '석고수정', '훼손', '훼손', '훼손', '오타공', '훼손',
#        '오염', '꼬임', '훼손', '터짐', '훼손', '터짐', '오타공',
#        '훼손', '훼손', '걸레받이수정', '오염', '훼손', '오염',
#        '곰팡이', '면불량', '훼손', '꼬임', '훼손', '훼손',
#        '훼손', '오염', '훼손', '터짐', '오염', '훼손', '오염',
#        '훼손', '터짐', '훼손', '훼손', '훼손', '훼손', '훼손',
#        '오염', '오염', '훼손', '피스', '훼손', '오염', '오염',
#        '훼손', '훼손', '훼손', '녹오염', '터짐', '훼손', '오염',
#        '훼손', '훼손', '훼손', '훼손', '훼손', '훼손', '오염',
#        '훼손', '창틀,문틀수정', '오염', '꼬임', '훼손', '오염',
#        '훼손', '곰팡이', '오염', '훼손', '훼손', '곰팡이',
#        '오염', '훼손', '오염', '훼손', '면불량', '훼손', '오염',
#        '오염', '훼손', '훼손', '오염', '오타공', '오염',
#        '면불량', '오염', '오염', '훼손', '몰딩수정', '꼬임',
#        '오타공', '오염', '훼손', '훼손', '훼손', '오염', '오염',
#        '훼손', '훼손', '훼손', '터짐', '훼손', '훼손', '훼손',
#        '훼손', '훼손', '오염', '훼손', '훼손', '곰팡이', '훼손',
#        '터짐', '오염', '들뜸', '훼손'], dtype=object)

# %% [markdown]
# ## Submission

# %%
submit = pd.read_csv('drive/MyDrive/Doedal/sample_submission.csv')

# %%
submit['label'] = result

# %%
submit
# Out:
#            id   label
# 0    TEST_000   훼손
# 1    TEST_001   오염
# 2    TEST_002   훼손
# 3    TEST_003   훼손
# 4    TEST_004   오염
# ..        ...     ...
# 787  TEST_787   훼손
# 788  TEST_788   터짐
# 789  TEST_789   오염
# 790  TEST_790  들뜸
# 791  TEST_791   훼손
#
# [792 rows x 2 columns]

# %%
import chardet

print(chardet.detect(submit['label'][0].encode()))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
# 인코딩 오류 수정하는 코드(자음 모음 분리 합쳐줌)
import unicodedata

for i in range(len(submit['label'])):
  submit['label'][i] = unicodedata.normalize('NFC',submit['label'][i])

# %%
submit['label'][0]
# Out:
# '훼손'

# %%
print(chardet.detect(submit['label'][0].encode()))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.7525, 'language': ''}

# %%
submit.to_csv('drive/MyDrive/Doedal/baseline_submit_3.csv', index=False)
